# %%
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer
from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from scipy.spatial.distance import cosine
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest
import re
import string
from wordcloud import WordCloud, STOPWORDS
from sklearn.metrics import mean_squared_error

# %%
from afinn import Afinn
afinn = Afinn()

# %%
df = pd.read_csv('/Users/varsha/.spyder-py3/Scott.csv')

df.head(3)
# Out:
#                                                tweet           Created-At  \
# 0  Heidi ?? ??️‍?? ✊???????? on Twitter: &quot;Mo...  2018-10-23 15:49:07
# 1  VoteVets on Twitter: &quot;Another verdict on ...  2018-10-23 14:33:31
# 2  #ThePersistence on Twitter: &quot;FL, vote for...  2018-10-22 00:27:03
#
#                    From-User  Retweet-Count Account            Id
# 0  Heidi ?? ??️‍?? ✊????????            0.0   Scott  1.054822e+18
# 1                   VoteVets          311.0   Scott  1.054803e+18
# 2            #ThePersistence          650.0   Scott  1.054228e+18

# %%
# Sentiment analysis with AFINN
afinn = Afinn(emoticons=True)
afinn_scores = [afinn.score(text) for text in df.tweet]
df['afinn'] = afinn_scores

# %%
#compute sentiment scores (polarity) and labels
sentiment_scores = [afinn.score(text) for text in df.tweet]
sentiment_category = ['positive' if score > 0 
                          else 'negative' if score < 0 
                              else 'neutral' 
                                  for score in sentiment_scores]

# %%
df1 = pd.DataFrame([list(df['tweet']), sentiment_scores, sentiment_category]).T
df1.columns = ['tweet', 'sentiment_scores', 'sentiment_category']
df1['sentiment_scores'] = df1.sentiment_scores.astype('float')
df1.groupby(by=['tweet']).describe()
# Out:
#                                                    sentiment_scores        \
#                                                               count  mean
# tweet
# #ThePersistence on Twitter: &quot;FL, vote for ...              1.0   0.0
# ????????VB ????????Nationalist⭐️⭐️⭐️ on Twitter...              1.0   5.0
# ??Blue House: 100+ Women &amp; POC! on Twitter:...              1.0  -4.0
# @AMErikaNGIRLBOT: Attention Florida ! #VoteHimO...              4.0  -3.0
# @AndrewGillum: .@NelsonForSenate has been a tir...              1.0   2.0
# @Anncostanza1: @1776HotLips @RonDeSantisFL If y...              2.0   6.0
# @AuntCinnamon: ???? ???? ???? VOTE ???? ???? ??...              1.0   3.0
# @Autism_Strong @ScottPresler @RonDeSantisFL @Sc...              1.0   5.0
# @BeachGatorFL: .@RNRFlorida @POTUS @realDonaldT...             13.0   0.0
# @BeachGatorFL: .@realDonaldTrump @POTUS \n?????...              2.0   0.0
# @CampagnaTerry: @ScottforFlorida @DanWantsFreed...              1.0   2.0
# @CatSocialist: @FLGovScott @ScottforFlorida @FL...              2.0   1.0
# @ConservativePTZ @RonDeSantisFL @ScottforFlorid...              1.0   0.0
# @ConservativePTZ: Sonny has an important messag...              2.0   2.0
# @DharmaMum: @ScottforFlorida Strange that #30A ...              2.0  -1.0
# @Eightofnine8: @ScottPresler @RonDeSantisFL @Sc...              2.0   1.0
# @Feisty_FL @RonDeSantisFL @ScottforFlorida Love...              1.0   9.0
# @Feisty_FL: I just early voted with my #MAGA ha...              4.0   0.0
# @FeralKarma @ScottforFlorida @RonDeSantisFL Orl...              1.0  -1.0
# @FloridaGOP: New polling shows @ScottforFlorida...              1.0   2.0
# @FloridaGOP: Spotted: Large chicken outside of ...              2.0   0.0
# @Gamers4Scott: Wow amazing! @RonDeSantisFL did ...              4.0  12.0
# @Germantownrunne: @ScottPresler @davhalter @Ron...              1.0   0.0
# @JOHN3_15: @ScottPresler @trumptrain1111 @Scott...              1.0   2.0
# @KyleKashuv: It’s time Florida relieves @SenBil...              4.0  -2.0
# @LWN_: @ScottforFlorida #RedTideRick ??\n"Durin...              1.0   2.0
# @LarrySchweikart: @mrmonks01 @TedCornwell @RonD...              1.0   0.0
# @LarrySchweikart: @mrmonks01 @TedCornwell @RonD...              1.0   0.0
# @NGivasDC: Florida Gov Rick Scott Calls Out Sen...              1.0  -1.0
# @NancyIncocoa: @Danager27 @alley167 @RonDeSanti...              1.0   0.0
# ...                                                             ...   ...
# Kummsss on Twitter: &quot;You listed two that I...              1.0  -3.0
# Lori Brolin-Zizza on Twitter: &quot;Did you wat...              1.0   0.0
# Lori Brolin-Zizza on Twitter: &quot;I&#39;m Pre...              1.0  -2.0
# Nan50 on Twitter: &quot;I am brow beating every...              1.0   0.0
# Nat Atkins on Twitter: &quot;We&#39;re lucking ...              1.0  10.0
# Nationalist Kevin on Twitter: &quot;#Florida FL...              1.0   1.0
# Nationalist Matt⭐️⭐️⭐️ on Twitter: &quot;@Andre...              1.0   0.0
# Not My Cheato on Twitter: &quot;Oh look another...              1.0   6.0
# Paul Magdalin on Twitter: &quot;Is that what Mi...              1.0   0.0
# Public Nuisance on Twitter: &quot;Rick Scott ig...              1.0   1.0
# RY on Twitter: &quot;And @RonDeSantisFL will ma...              1.0  -4.0
# Rick Scott on Twitter: &quot;Good luck @RonDeSa...              1.0   9.0
# Robert McLaws on Twitter: &quot;Wow, ⁦@Scottfor...              1.0   4.0
# Rochelle Swanson on Twitter: &quot;Wow!&#10;&#1...              1.0   6.0
# Rocket44 ???? on Twitter: &quot;I&#39;m early v...              1.0   1.0
# SOUTHERN NATIONALIST TROLL on Twitter: &quot;Fl...              1.0  -2.0
# SStone on Twitter: &quot;He bombed. Florida alr...              1.0   2.0
# TOᑭ ᖇOᑭE TᖇAViS on Twitter: &quot;Rick Scott sa...              1.0   8.0
# TeHenderson on Twitter: &quot;Wait til the ille...              1.0  -3.0
# Terry Campagna on Twitter: &quot;All ready vote...              1.0   5.0
# Thomas Clark on Twitter: &quot;Yep, you want to...              1.0  -1.0
# Upholding Truth on Twitter: &quot;It was obviou...              1.0   2.0
# ValVal007 on Twitter: &quot;The biggest &quot;t...              1.0  -4.0
# Victorious Annie ???????? on Twitter: &quot;If ...              1.0   7.0
# VoteVets on Twitter: &quot;Another verdict on o...              1.0  -1.0
# donna januario on Twitter: &quot;Andrew Gillum ...              1.0   3.0
# kat ?? #Trump2020Landslide on Twitter: &quot;No...              1.0  -1.0
# kat ?? #Trump2020Landslide on Twitter: &quot;Th...              1.0   0.0
# wladimir on Twitter: &quot;Florida is Trump Cou...              1.0   4.0
# ♿️????????Alabama4Trump  MAGAveteran  ⭐️⭐️⭐️ on...              1.0  13.0
#
#                                                                            \
#                                                     std   min   25%   50%
# tweet
# #ThePersistence on Twitter: &quot;FL, vote for ...  NaN   0.0   0.0   0.0
# ????????VB ????????Nationalist⭐️⭐️⭐️ on Twitter...  NaN   5.0   5.0   5.0
# ??Blue House: 100+ Women &amp; POC! on Twitter:...  NaN  -4.0  -4.0  -4.0
# @AMErikaNGIRLBOT: Attention Florida ! #VoteHimO...  0.0  -3.0  -3.0  -3.0
# @AndrewGillum: .@NelsonForSenate has been a tir...  NaN   2.0   2.0   2.0
# @Anncostanza1: @1776HotLips @RonDeSantisFL If y...  0.0   6.0   6.0   6.0
# @AuntCinnamon: ???? ???? ???? VOTE ???? ???? ??...  NaN   3.0   3.0   3.0
# @Autism_Strong @ScottPresler @RonDeSantisFL @Sc...  NaN   5.0   5.0   5.0
# @BeachGatorFL: .@RNRFlorida @POTUS @realDonaldT...  0.0   0.0   0.0   0.0
# @BeachGatorFL: .@realDonaldTrump @POTUS \n?????...  0.0   0.0   0.0   0.0
# @CampagnaTerry: @ScottforFlorida @DanWantsFreed...  NaN   2.0   2.0   2.0
# @CatSocialist: @FLGovScott @ScottforFlorida @FL...  0.0   1.0   1.0   1.0
# @ConservativePTZ @RonDeSantisFL @ScottforFlorid...  NaN   0.0   0.0   0.0
# @ConservativePTZ: Sonny has an important messag...  0.0   2.0   2.0   2.0
# @DharmaMum: @ScottforFlorida Strange that #30A ...  0.0  -1.0  -1.0  -1.0
# @Eightofnine8: @ScottPresler @RonDeSantisFL @Sc...  0.0   1.0   1.0   1.0
# @Feisty_FL @RonDeSantisFL @ScottforFlorida Love...  NaN   9.0   9.0   9.0
# @Feisty_FL: I just early voted with my #MAGA ha...  0.0   0.0   0.0   0.0
# @FeralKarma @ScottforFlorida @RonDeSantisFL Orl...  NaN  -1.0  -1.0  -1.0
# @FloridaGOP: New polling shows @ScottforFlorida...  NaN   2.0   2.0   2.0
# @FloridaGOP: Spotted: Large chicken outside of ...  0.0   0.0   0.0   0.0
# @Gamers4Scott: Wow amazing! @RonDeSantisFL did ...  0.0  12.0  12.0  12.0
# @Germantownrunne: @ScottPresler @davhalter @Ron...  NaN   0.0   0.0   0.0
# @JOHN3_15: @ScottPresler @trumptrain1111 @Scott...  NaN   2.0   2.0   2.0
# @KyleKashuv: It’s time Florida relieves @SenBil...  0.0  -2.0  -2.0  -2.0
# @LWN_: @ScottforFlorida #RedTideRick ??\n"Durin...  NaN   2.0   2.0   2.0
# @LarrySchweikart: @mrmonks01 @TedCornwell @RonD...  NaN   0.0   0.0   0.0
# @LarrySchweikart: @mrmonks01 @TedCornwell @RonD...  NaN   0.0   0.0   0.0
# @NGivasDC: Florida Gov Rick Scott Calls Out Sen...  NaN  -1.0  -1.0  -1.0
# @NancyIncocoa: @Danager27 @alley167 @RonDeSanti...  NaN   0.0   0.0   0.0
# ...                                                 ...   ...   ...   ...
# Kummsss on Twitter: &quot;You listed two that I...  NaN  -3.0  -3.0  -3.0
# Lori Brolin-Zizza on Twitter: &quot;Did you wat...  NaN   0.0   0.0   0.0
# Lori Brolin-Zizza on Twitter: &quot;I&#39;m Pre...  NaN  -2.0  -2.0  -2.0
# Nan50 on Twitter: &quot;I am brow beating every...  NaN   0.0   0.0   0.0
# Nat Atkins on Twitter: &quot;We&#39;re lucking ...  NaN  10.0  10.0  10.0
# Nationalist Kevin on Twitter: &quot;#Florida FL...  NaN   1.0   1.0   1.0
# Nationalist Matt⭐️⭐️⭐️ on Twitter: &quot;@Andre...  NaN   0.0   0.0   0.0
# Not My Cheato on Twitter: &quot;Oh look another...  NaN   6.0   6.0   6.0
# Paul Magdalin on Twitter: &quot;Is that what Mi...  NaN   0.0   0.0   0.0
# Public Nuisance on Twitter: &quot;Rick Scott ig...  NaN   1.0   1.0   1.0
# RY on Twitter: &quot;And @RonDeSantisFL will ma...  NaN  -4.0  -4.0  -4.0
# Rick Scott on Twitter: &quot;Good luck @RonDeSa...  NaN   9.0   9.0   9.0
# Robert McLaws on Twitter: &quot;Wow, ⁦@Scottfor...  NaN   4.0   4.0   4.0
# Rochelle Swanson on Twitter: &quot;Wow!&#10;&#1...  NaN   6.0   6.0   6.0
# Rocket44 ???? on Twitter: &quot;I&#39;m early v...  NaN   1.0   1.0   1.0
# SOUTHERN NATIONALIST TROLL on Twitter: &quot;Fl...  NaN  -2.0  -2.0  -2.0
# SStone on Twitter: &quot;He bombed. Florida alr...  NaN   2.0   2.0   2.0
# TOᑭ ᖇOᑭE TᖇAViS on Twitter: &quot;Rick Scott sa...  NaN   8.0   8.0   8.0
# TeHenderson on Twitter: &quot;Wait til the ille...  NaN  -3.0  -3.0  -3.0
# Terry Campagna on Twitter: &quot;All ready vote...  NaN   5.0   5.0   5.0
# Thomas Clark on Twitter: &quot;Yep, you want to...  NaN  -1.0  -1.0  -1.0
# Upholding Truth on Twitter: &quot;It was obviou...  NaN   2.0   2.0   2.0
# ValVal007 on Twitter: &quot;The biggest &quot;t...  NaN  -4.0  -4.0  -4.0
# Victorious Annie ???????? on Twitter: &quot;If ...  NaN   7.0   7.0   7.0
# VoteVets on Twitter: &quot;Another verdict on o...  NaN  -1.0  -1.0  -1.0
# donna januario on Twitter: &quot;Andrew Gillum ...  NaN   3.0   3.0   3.0
# kat ?? #Trump2020Landslide on Twitter: &quot;No...  NaN  -1.0  -1.0  -1.0
# kat ?? #Trump2020Landslide on Twitter: &quot;Th...  NaN   0.0   0.0   0.0
# wladimir on Twitter: &quot;Florida is Trump Cou...  NaN   4.0   4.0   4.0
# ♿️????????Alabama4Trump  MAGAveteran  ⭐️⭐️⭐️ on...  NaN  13.0  13.0  13.0
#
#
#                                                      75%   max
# tweet
# #ThePersistence on Twitter: &quot;FL, vote for ...   0.0   0.0
# ????????VB ????????Nationalist⭐️⭐️⭐️ on Twitter...   5.0   5.0
# ??Blue House: 100+ Women &amp; POC! on Twitter:...  -4.0  -4.0
# @AMErikaNGIRLBOT: Attention Florida ! #VoteHimO...  -3.0  -3.0
# @AndrewGillum: .@NelsonForSenate has been a tir...   2.0   2.0
# @Anncostanza1: @1776HotLips @RonDeSantisFL If y...   6.0   6.0
# @AuntCinnamon: ???? ???? ???? VOTE ???? ???? ??...   3.0   3.0
# @Autism_Strong @ScottPresler @RonDeSantisFL @Sc...   5.0   5.0
# @BeachGatorFL: .@RNRFlorida @POTUS @realDonaldT...   0.0   0.0
# @BeachGatorFL: .@realDonaldTrump @POTUS \n?????...   0.0   0.0
# @CampagnaTerry: @ScottforFlorida @DanWantsFreed...   2.0   2.0
# @CatSocialist: @FLGovScott @ScottforFlorida @FL...   1.0   1.0
# @ConservativePTZ @RonDeSantisFL @ScottforFlorid...   0.0   0.0
# @ConservativePTZ: Sonny has an important messag...   2.0   2.0
# @DharmaMum: @ScottforFlorida Strange that #30A ...  -1.0  -1.0
# @Eightofnine8: @ScottPresler @RonDeSantisFL @Sc...   1.0   1.0
# @Feisty_FL @RonDeSantisFL @ScottforFlorida Love...   9.0   9.0
# @Feisty_FL: I just early voted with my #MAGA ha...   0.0   0.0
# @FeralKarma @ScottforFlorida @RonDeSantisFL Orl...  -1.0  -1.0
# @FloridaGOP: New polling shows @ScottforFlorida...   2.0   2.0
# @FloridaGOP: Spotted: Large chicken outside of ...   0.0   0.0
# @Gamers4Scott: Wow amazing! @RonDeSantisFL did ...  12.0  12.0
# @Germantownrunne: @ScottPresler @davhalter @Ron...   0.0   0.0
# @JOHN3_15: @ScottPresler @trumptrain1111 @Scott...   2.0   2.0
# @KyleKashuv: It’s time Florida relieves @SenBil...  -2.0  -2.0
# @LWN_: @ScottforFlorida #RedTideRick ??\n"Durin...   2.0   2.0
# @LarrySchweikart: @mrmonks01 @TedCornwell @RonD...   0.0   0.0
# @LarrySchweikart: @mrmonks01 @TedCornwell @RonD...   0.0   0.0
# @NGivasDC: Florida Gov Rick Scott Calls Out Sen...  -1.0  -1.0
# @NancyIncocoa: @Danager27 @alley167 @RonDeSanti...   0.0   0.0
# ...                                                  ...   ...
# Kummsss on Twitter: &quot;You listed two that I...  -3.0  -3.0
# Lori Brolin-Zizza on Twitter: &quot;Did you wat...   0.0   0.0
# Lori Brolin-Zizza on Twitter: &quot;I&#39;m Pre...  -2.0  -2.0
# Nan50 on Twitter: &quot;I am brow beating every...   0.0   0.0
# Nat Atkins on Twitter: &quot;We&#39;re lucking ...  10.0  10.0
# Nationalist Kevin on Twitter: &quot;#Florida FL...   1.0   1.0
# Nationalist Matt⭐️⭐️⭐️ on Twitter: &quot;@Andre...   0.0   0.0
# Not My Cheato on Twitter: &quot;Oh look another...   6.0   6.0
# Paul Magdalin on Twitter: &quot;Is that what Mi...   0.0   0.0
# Public Nuisance on Twitter: &quot;Rick Scott ig...   1.0   1.0
# RY on Twitter: &quot;And @RonDeSantisFL will ma...  -4.0  -4.0
# Rick Scott on Twitter: &quot;Good luck @RonDeSa...   9.0   9.0
# Robert McLaws on Twitter: &quot;Wow, ⁦@Scottfor...   4.0   4.0
# Rochelle Swanson on Twitter: &quot;Wow!&#10;&#1...   6.0   6.0
# Rocket44 ???? on Twitter: &quot;I&#39;m early v...   1.0   1.0
# SOUTHERN NATIONALIST TROLL on Twitter: &quot;Fl...  -2.0  -2.0
# SStone on Twitter: &quot;He bombed. Florida alr...   2.0   2.0
# TOᑭ ᖇOᑭE TᖇAViS on Twitter: &quot;Rick Scott sa...   8.0   8.0
# TeHenderson on Twitter: &quot;Wait til the ille...  -3.0  -3.0
# Terry Campagna on Twitter: &quot;All ready vote...   5.0   5.0
# Thomas Clark on Twitter: &quot;Yep, you want to...  -1.0  -1.0
# Upholding Truth on Twitter: &quot;It was obviou...   2.0   2.0
# ValVal007 on Twitter: &quot;The biggest &quot;t...  -4.0  -4.0
# Victorious Annie ???????? on Twitter: &quot;If ...   7.0   7.0
# VoteVets on Twitter: &quot;Another verdict on o...  -1.0  -1.0
# donna januario on Twitter: &quot;Andrew Gillum ...   3.0   3.0
# kat ?? #Trump2020Landslide on Twitter: &quot;No...  -1.0  -1.0
# kat ?? #Trump2020Landslide on Twitter: &quot;Th...   0.0   0.0
# wladimir on Twitter: &quot;Florida is Trump Cou...   4.0   4.0
# ♿️????????Alabama4Trump  MAGAveteran  ⭐️⭐️⭐️ on...  13.0  13.0
#
# [188 rows x 8 columns]

# %%
#function for tokenizing summary
regEx = re.compile('[^a-z]+')
def cleanReviews(reviewText):
    reviewText = reviewText.lower()
    reviewText = regEx.sub(' ', reviewText).strip()
    return reviewText

cluster = df1.groupby("sentiment_scores")["tweet"].apply(list)
cluster = pd.DataFrame(cluster)
cluster.to_csv("cluster.csv")
cluster1 = pd.read_csv("cluster.csv")
cluster1["TextClean"] = cluster1["tweet"].apply(cleanReviews)

# %%
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

# %%
def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords = stopwords,
        max_words=500,
        max_font_size=30, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))
    
    fig = plt.figure(1, figsize=(8, 8))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %%
df1["sentiment_category"].describe()
# Out:
# count          888
# unique           3
# top       positive
# freq           485
# Name: sentiment_category, dtype: object

# %%
#Wordcloud on unclean data       
#category 0 -neutral
show_wordcloud(cluster['tweet'][0], title ="sentiment")

# %%
#Wordcloud on unclean data       
#category 1 -positive
show_wordcloud(cluster['tweet'][1], title ="sentiment")

# %%
#Wordcloud on unclean data       
#category 2 - negative
show_wordcloud(cluster['tweet'][2], title ="sentiment")

# %%
#Wordcloud on cleaned data      
#category 0
show_wordcloud(cluster1['tweet'][0], title ="sentiment_Neutral")

# %%
show_wordcloud(cluster1['tweet'][1], title ="sentiment_Positive")

# %%
show_wordcloud(cluster1['tweet'][2], title ="sentiment_Negative")

# %%
df1["sentiment_category"].unique()
# Out:
# array(['negative', 'neutral', 'positive'], dtype=object)
